# %% [markdown]
# <a href="https://colab.research.google.com/github/jerry-mouse-2333/colab_save/blob/master/raw_dataset_h5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import h5py
from PIL import Image
from sklearn.model_selection import train_test_split
import numpy as np

# %%
#从文件夹中读取图片
def read_image(img_name):

    #im = Image.open(img_name).convert('L')
    # im = im.resize((128,128))
    im = Image.open(img_name)
    data = np.array(im)
    # data = np.array(im).astype("float32")/255.0
    
    return data

# %% [markdown]
# ## a test for "是不是乱序的，能否正常读取等”

# %%
import matplotlib.pyplot as plt
images = []
target_dir="/content/drive/Shared drives/shared/datasetxuhao"

i=0
for fn in os.listdir(target_dir):
    
    img_path=os.path.join(target_dir,fn)
    
    if fn.endswith('.jpg'):
      fn = Image.open(img_path)
      
      #图片转换成numpy
      #即时输出类型: result:unit8
      fn = np.array(fn)
      print(fn.type)

      #转换成float32
      fn = fn.astype("float32")/255.0
      plt.imshow(fn)
        #cv2.waitKey()
      break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-4012cd2fc7ae> in <module>()
#      14       #即时输出类型
#      15       fn = np.array(fn)
# ---> 16       print(fn.type)
#      17
#      18       #转换成float32
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
import matplotlib.pyplot as plt
images = []
target_dir="/content/drive/Shared drives/shared/datasetxuhao"

i=0
for fn in os.listdir(target_dir):
        if i>=9000:
          break
        fd = os.path.join(target_dir,fn)

        images.append(read_image(fd))
        if(i%1000==0):
          print(i)
        i+=1

print('total num:',i)

X = np.array(images)

X_train, X_test = train_test_split(X, test_size = 0.2, random_state= 50)

print (X.shape)
#(480,640)

save_path = os.path.join("/content/drive/My Drive","raw_dataset.h5")
f=h5py.File(save_path,'w')
f['X_train']=X_train
f['X_test']=X_test
test=X_test[8].astype("float32")/255.0
plt.imshow(test)
plt.imshow(X_test[8])
f.close()
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# total num: 9000
# (9000, 480, 640, 3)

# %%
i=0
for _ in range(100):
  # print(_)
  if(i>50):
    break
  i+=1
  #print(i)
  if(i%10==0):
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50
